# %%
import cdt
# Out:
#  ------------------------
# You are now playing Hiking the Continental Divide Trail!
#
#            ,                        '           .        '        ,
#    .            .        '       .         ,
#                                                    .       '     +
#        +          .```````.
#                 .'         `.   +     .     ________||
#        ___     :             :     |       /        ||  .     '___
#   ____/   \   :               :   ||.    _/      || ||\_______/   \
#  /         \  :      _/|      :   `|| __/      ,.|| ||             \
# /  ,   '  . \  :   =/_/      :     |'_______     || ||  ||   .      \
#     |        \__`._/ |     .'   ___|        \__   \||  ||...    ,   \
#    l|,   '   (   /  ,|...-'        \   '   ,     __\||_//___
#  ___|____     \_/^\/||__    ,    .  ,__             ||//    \    .  ,
#            _/~  `""~`"` \_           ''(       ....,||/       '
#  ..,...  __/  -'/  `-._ `\_\__        | \           ||  _______   .
# ...
